# %% [markdown]
# # Carga de datos a traves de la función read_csv

# %%
# librerias
import pandas as pd
import os

# %%
# Rutas de los ficheros de datos
minpath = "/Users/garciae1/Documents/GitHub/python-ml-course/datasets"
filename = "titanic/titanic3.csv"
fullpath = os.path.join (minpath, filename)

# %%
# leer datos de csv
data = pd.read_csv(fullpath)
# ver el tipo de objeto
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# muestra primeros registros
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# leer datos de txt
data2 = pd.read_csv(minpath + "/" + "customer-churn-model/Customer Churn Model.txt")
data2.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
# sacar cabeceras
data2.columns.values
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
# Leer csv de cabeceras
data_cols = pd.read_csv(minpath + "/" + "customer-churn-model/Customer Churn Columns.csv")
# convierte el objeto a lista
data_cols_list = data_cols["Column_Names"].tolist()
# leemos csv de datos y le ponemos de cabecera la lista del paso anterior
data2 = pd.read_csv(minpath + "/" + "customer-churn-model/Customer Churn Model.txt", header = None, 
                    names = data_cols_list,skiprows=1)
data2.head()
# Out:
#     A    B    C         D    E    F   G      H    I      J   ...      L  \
# 0  KS  128  415  382-4657   no  yes  25  265.1  110  45.07   ...     99
# 1  OH  107  415  371-7191   no  yes  26  161.6  123  27.47   ...    103
# 2  NJ  137  415  358-1921   no   no   0  243.4  114  41.38   ...    110
# 3  OH   84  408  375-9999  yes   no   0  299.4   71  50.90   ...     88
# 4  OK   75  415  330-6626  yes   no   0  166.7  113  28.34   ...    122
#
#        M      N    O      P     Q  R     S  T       U
# 0  16.78  244.7   91  11.01  10.0  3  2.70  1  False.
# 1  16.62  254.4  103  11.45  13.7  3  3.70  1  False.
# 2  10.30  162.6  104   7.32  12.2  5  3.29  0  False.
# 3   5.26  196.9   89   8.86   6.6  7  1.78  2  False.
# 4  12.61  186.9  121   8.41  10.1  3  2.73  3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# # Carga de datos a traves de la función OPEN

# %%
# abrir fichero para lectura
data3 = open (minpath + "/" + "customer-churn-model/Customer Churn Model.txt", "r")
type(data3)
data3
# Out:
# <_io.TextIOWrapper name='/Users/garciae1/Documents/GitHub/python-ml-course/datasets/customer-churn-model/Customer Churn Model.txt' mode='r' encoding='cp1252'>

# %%
# cada vez que se ejecuta lee la siguiente linea
# strip limpia espacios
# split indica el separador de campos
cols = data3.readline().strip().split(",")
# saca el numero de campos
n_cols = len(cols)
n_cols
# muestra el registro
cols
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
#crear un diccionario que almacene la clave (contador que se incrementa de 0 a n)
#como valor asociado a esa clave los valores del registro leido. 

# contador de filas
counter=0
#Inicializa el diccionario
main_dict={}
# Por cada registro
for col in cols:
    # inicializa el diccionario poniendo como clave cada campo de la cabecera
    main_dict[col]=[]
main_dict
# Out:
# {'State': [],
#  'Account Length': [],
#  'Area Code': [],
#  'Phone': [],
#  "Int'l Plan": [],
#  'VMail Plan': [],
#  'VMail Message': [],
#  'Day Mins': [],
#  'Day Calls': [],
#  'Day Charge': [],
#  'Eve Mins': [],
#  'Eve Calls': [],
#  'Eve Charge': [],
#  'Night Mins': [],
#  'Night Calls': [],
#  'Night Charge': [],
#  'Intl Mins': [],
#  'Intl Calls': [],
#  'Intl Charge': [],
#  'CustServ Calls': [],
#  'Churn?': []}

# %%
# por cada linea de datos leida
for line in data3:
    # en values guarda los datos sin espacios e indicando que estan separados por coma
    values=line.strip().split(",")
    # desde i=0 hasta el total de columnas
    for i in range(len(cols)):
        # en la clave [x] del diccionario guarda los valores de la columna [x] del dataset
        main_dict[cols[i]].append(values[i])
    # aumenta el contador de filas    
    counter += 1

print ("El dataset tiene %d filas y %d columnas" %(counter, n_cols))
# Out:
# El dataset tiene 3333 filas y 21 columnas

# %%
# sacar claves del diccionario
main_dict.keys()
# Out:
# dict_keys(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan", 'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge', 'CustServ Calls', 'Churn?'])

# %%
# sacar un valor por la clave
print (main_dict["Account Length"])
# Out:
# ['128', '107', '137', '84', '75', '118', '121', '147', '117', '141', '65', '74', '168', '95', '62', '161', '85', '93', '76', '73', '147', '77', '130', '111', '132', '174', '57', '54', '20', '49', '142', '75', '172', '12', '57', '72', '36', '78', '136', '149', '98', '135', '34', '160', '64', '59', '65', '142', '119', '97', '52', '60', '10', '96', '87', '81', '141', '121', '68', '125', '174', '116', '74', '149', '38', '40', '43', '113', '126', '150', '138', '162', '147', '90', '85', '50', '82', '144', '46', '70', '144', '116', '55', '70', '106', '128', '94', '111', '74', '128', '82', '155', '80', '78', '90', '104', '73', '99', '120', '77', '98', '108', '135', '95', '122', '95', '36', '93', '141', '157', '120', '103', '98', '125', '63', '36', '64', '74', '112', '97', '46', '41', '121', '193', '130', '85', '162', '61', '92', '131', '90', '75', '78', '82', '163', '91', '75', '91', '127', '113', '110', '120', '157', '103', '117', '140', '127', '83', '121', '145', '113', '117', '65', '56', 
# ...

# %%
# almaceno en un dataframe el contenido del diccionario
df3  = pd.DataFrame(main_dict)
df3.head()
# Out:
#   State Account Length Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS            128       415  382-4657         no        yes
# 1    OH            107       415  371-7191         no        yes
# 2    NJ            137       415  358-1921         no         no
# 3    OH             84       408  375-9999        yes         no
# 4    OK             75       415  330-6626        yes         no
#
#   VMail Message    Day Mins Day Calls Day Charge   ...   Eve Calls Eve Charge  \
# 0            25  265.100000       110  45.070000   ...          99  16.780000
# 1            26  161.600000       123  27.470000   ...         103  16.620000
# 2             0  243.400000       114  41.380000   ...         110  10.300000
# 3             0  299.400000        71  50.900000   ...          88   5.260000
# 4             0  166.700000       113  28.340000   ...         122  12.610000
#
#    Night Mins Night Calls Night Charge  Intl Mins Intl Calls Intl Charge  \
# ...

# %% [markdown]
# ## Lectura y escritura de ficheros

# %%
#Ficheros de lectura y escritura
infile = minpath + "/" + "customer-churn-model/Customer Churn Model.txt"
outfile = minpath + "/" + "customer-churn-model/Tab Customer Churn Model.txt"

# %%
# abre los ficheros indicando el modo ("r" o "w") y los asigna a variables
with open(infile, "r") as infile1:
    with open(outfile, "w") as outfile1:
        # por cada linea del ficnhero de entrada
        for line in infile1:
            # limpia la linea
            fields = line.strip().split(",")
            # Une los campos por tabulador
            outfile1.write("\t".join(fields))
            # pone salto de linea
            outfile1.write("\n")

# %%
# leemos el fichero de salida indicando que esta separado por tabulador
df4 = pd.read_csv(outfile, sep = "\t")
df4.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# # leer datos desde una URL

# %%
medals_url = "http://winterolympicsmedals.com/medals.csv"
medals_data = pd.read_csv(medals_url)
medals_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# # Ejercicio de carga de datos con urllib3

# %%
# uso del paquete urllib3 para leer datos de url
import urllib3
medals_url = "http://winterolympicsmedals.com/medals.csv"
http = urllib3.PoolManager()
r = http.request("GET", medals_url)
r.status

# devuelve el valor tipo bytes y lo paso a string
response = r.data.decode(encoding="utf-8")

# separo las lineas por el separador \n
lines = response.strip().split('\n')

# La primera linea es la cabecera
cols = lines[0].strip().split(',')

#diccionario que almacene la clave (contador que se incrementa de 0 a n)
#como valor asociado a esa clave los valores del registro leido. 
# contador de filas
counter=0
#Inicializa el diccionario
medals_dict={}
# Por cada registro
for col in cols:
    # inicializa el diccionario poniendo como clave cada campo de la cabecera
    medals_dict[col]=[]

medals_dict

# por cada linea de datos leida
for line in lines[1:]:
    # en values guarda los datos sin espacios e indicando que estan separados por coma
    values=line.strip().split(",")
    # desde i=0 hasta el total de columnas
    for i in range(len(cols)):
        # en la clave [x] del diccionario guarda los valores de la columna [x] del dataset
        medals_dict[cols[i]].append(values[i])
    # aumenta el contador de filas    
    counter += 1

#print ("El dataset tiene %d filas y %d columnas" %(counter, n_cols))
df3  = pd.DataFrame(medals_dict)
df3.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# # # ficheros XLS y XLSX

# %%
minpath = "/Users/garciae1/Documents/GitHub/python-ml-course/datasets"
filename = "titanic/titanic3.xls"
titanic2 = pd.read_excel (minpath + "/" + filename, "titanic3")
titanic2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
minpath = "/Users/garciae1/Documents/GitHub/python-ml-course/datasets"
filename = "titanic/titanic3.xlsx"
titanic3 = pd.read_excel (minpath + "/" + filename, "titanic3")
titanic3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic3.to_csv(minpath + "/titanic/titanic_custom2.csv")

# %%
titanic3.to_excel(minpath + "/titanic/titanic_custom2.xls")

# %%
titanic3.to_json(minpath + "/titanic/titanic_custom2.json")
